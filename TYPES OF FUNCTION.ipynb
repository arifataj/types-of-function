# %% [markdown]
# Lambda functions are similar to user defined function but without a name .
# They are commonly reffered to as anonymous function.
#
# Syntax :
# lambda arguments(s):expression
#
# lambda is a key word in python for defining the anonymous function.
# arguments() is a placeholder, that is a variable thet will be used to hold the value you want to pass into the function expression . A lambda function can have multiple variables depending on what you want to achive.
# expression is the code you want to execute in the lambda function

# %%
#hello

OLLEH

# %%
#user defined function
def functionnames (n1 , n2):

  expression

# %%
def exp(x):

  return x ** 2

exp(5)
# Out:
# 25

# %%
x = lambda x : x**2

print(x(4))
# Out:
# 16

# %%
print((lambda x : x** 2)(4))
# Out:
# 16

# %%
print((lambda x : x** 2)(2))
# Out:
# 4

# %%
x = lambda x : x.upper ()[::-1]

print(x('hello'))
# Out:
# OLLEH

# %%
x = lambda x , y : x-y if x > y else y-x

print(x(2,4))
# Out:
# 2

# %% [markdown]
# n1,n2
#
# n1-n2
#
# n2-n1

# %%
x = lambda x : 'even' if x%2 == 0 else 'odd'

print(x(1))
# Out:
# odd

# %% [markdown]
# Filter():
#
# The filter function operator on a list and returns a subset of thet list after applying the filter rule. The function filter (f,,l)needs a function f as it arguments.f returns a boolean value ie either true or false . this function will be applied to every element of the list l. only if f returns true will element of the list l . only if f returns true will the element of the list l .only if f returns true will the element of the list be included in the result list.

# %%
list1 = [2,4,5,6,7,8,12,13,15,22]

x = filter (lambda x : x%2 == 0 , list1)

# %%
print((x))
# Out:
# <filter object at 0x7d35c8f03a30>

# %%
print(list(x))
# Out:
# [2, 4, 6, 8, 12, 22]

# %%
print(list(filter(lambda x : x%2 == 0 , list1)))
# Out:
# [2, 4, 6, 8, 12, 22]

# %%
list1 = ['raju','ramu','dolu', 'rema','bolu','anu']

print(list(filter(lambda x : x[0]== 'r' , list1)))
# Out:
# ['raju', 'ramu', 'rema']

# %% [markdown]
# # Maps ():
#
# The map()transforms a given list in to a new list in to a new list by transforming each element using a rule, it is used to apply a function to each element of a list or any other iterable
#
# This is very useful when we do vector mathematics, the map()function will take multiple list operates on then and return the output list,one thing to note is that all the list should be of the same size because map()applies the function to corresponding elements in those lists
#
#
# map()
#
# You use the map()function whenever you want to modify every value in itrerable

# %%
# list1 = [2,3,4,1]
#syntax of map()
#print (list(map(f,list1)))

# %%
list1 = [2,3,4,1]

print(list(map(lambda x : x**2 , list1)))
# Out:
# [4, 9, 16, 1]

# %%
x = 10
x ='shinas'

# %%
list1 = ['raju','ramu','bili','bolu','reema']

#list2 =  [True,True,False,False,True]

list2 = list(map(lambda name : name.startswith ==('r') , list1))

print(list2)
# Out:
# [False, False, False, False, False]

# %% [markdown]
# **Zip Function **
#
# The zip function take iterables (can be zero or more) makes iterators that aggregates elements based on the itrerable passed ,and retuns an iterable or tubles
#
# syntax:
#
# zip(*iterables)

# %%
#[2,3,4], [3,2,3] = ((2,3), (3,2)(4,3))

# %%
#[2,3,4],

# %%
#[2,3,4],['raju','bolu', 'dolu'] = ((2,'raju')), ('3', 'dolu'), (4,'bolu')

# %%
rn = [1,2,3]

name = ['raju','bolu','dolu']

data = list(zip(rn,name))

print(data)
# Out:
# [(1, 'raju'), (2, 'bolu'), (3, 'dolu')]

# %%
rn = [1,2,3]

name = ['raju','bolu','dolu']

data = tuple(zip(rn,name))

print(data)
# Out:
# ((1, 'raju'), (2, 'bolu'), (3, 'dolu'))

# %%
rn = [1,2,3]

name = ['raju','bolu','dolu']

data = dict(zip(rn,name))

print(data)
# Out:
# {1: 'raju', 2: 'bolu', 3: 'dolu'}
